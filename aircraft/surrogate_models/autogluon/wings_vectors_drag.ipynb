# %%
#surrogate models
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

data_name = 'wings'

data_file = f'../{data_name}_vectors_drags_lifts.csv'
df = TabularDataset(data_file)

train_df, test_df = train_test_split(df, test_size=0.2, random_state=777)

#exclue the first two columns of train data
train_data = train_df.drop(columns=['i', 'name'])
train_data.head()
# Out:
#         dim_1     dim_2     dim_3     dim_4     dim_5     dim_6     dim_7  \
# 406 -0.496165  1.705992  0.197353  1.742359  0.467517 -1.339144 -0.647645
# 54   0.033569  1.133478  1.176343 -0.943174 -0.657064 -0.401192  0.747147
# 241 -0.559282  0.308935 -0.047847 -1.081136  0.175241 -1.149952  0.719520
# 952 -0.222745  0.463468  0.462111  0.234607 -0.859618 -2.425318  0.684795
# 337  1.397874  0.460493 -1.091555 -0.442342  0.823289 -1.108367  0.877267
#
#         dim_8     dim_9    dim_10  ...   dim_121   dim_122   dim_123  \
# 406  0.697645  0.994912  0.193609  ... -0.770262 -0.448141 -0.866822
# 54   1.081339 -1.888797 -1.407570  ...  0.767994 -1.674341  0.346039
# 241  0.390920 -0.075074 -0.300515  ...  1.815440  0.596989  1.033692
# 952 -1.679074  1.190695 -0.385462  ... -2.272429  0.947205 -0.633594
# 337 -0.003360  0.461756 -0.804280  ... -1.359217 -1.532384  0.735832
#
#       dim_124   dim_125   dim_126   dim_127   dim_128   drag   lift
# 406 -2.491501  0.482521  0.362971  0.389367 -0.237259  0.395  0.425
# 54   0.387200 -0.006894  0.338835  0.207995  0.574507  0.645  0.885
# 241 -0.362098  0.247644  0.190097 -1.081548 -0.536878  0.446  0.756
# 952 -0.539486  0.290193 -0.221363 -1.451571  0.765826  0.384  0.177
# 337  0.230598  0.350978  0.722657 -0.155700 -0.851930  0.381  0.074
#
# [5 rows x 130 columns]

# %%
#save train_df to a csv file
train_df.to_csv('./train_df.csv', index=False)

# %%
#save test_df to a csv file
test_df.to_csv('./test_df.csv', index=False)

# %%
label = 'drag'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    837.000000
# mean       0.445233
# std        0.112500
# min        0.051000
# 25%        0.369000
# 50%        0.427000
# 75%        0.513000
# max        0.944000
# Name: drag, dtype: float64

# %%
import os
save_path = f'./agModels-{data_name}_{label}'  # specifies folder to store trained models
if not os.path.exists(save_path):
    os.makedirs(save_path)

bag_folds = 5 #suggestion range [5, 10]
bag_sets = 3 #suggestion range [1, 20]
stack_levels = 3 #suggestion range [0, 3]
metric = 'root_mean_squared_error' #Regression:mean_absolute_error, mean_squared_error,root_mean_squared_error (default), r2
predictor = TabularPredictor(label=label, path=save_path, eval_metric=metric).fit(train_data, 
                                                                                  presets='best_quality', 
                                                                                  auto_stack="True", 
                                                                                  num_bag_folds=bag_folds, 
                                                                                  num_bag_sets=bag_sets,
                                                                                  num_stack_levels=stack_levels,
                                                                                  verbosity=4)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="./agModels-wings_drag"
# Presets specified: ['best_quality']
# ============ fit kwarg info ============
# User Specified kwargs:
# {'auto_stack': 'True',
#  'num_bag_folds': 5,
#  'num_bag_sets': 3,
#  'num_stack_levels': 3,
#  'verbosity': 4}
# Full kwargs:
# {'_feature_generator_kwargs': None,
#  '_save_bag_folds': None,
#  'ag_args': None,
#  'ag_args_ensemble': None,
#  'ag_args_fit': None,
#  'auto_stack': 'True',
#  'calibrate': 'auto',
#  'excluded_model_types': None,
#  'feature_generator': 'auto',
#  'feature_prune_kwargs': None,
#  'holdout_frac': None,
#  'hyperparameter_tune_kwargs': None,
#  'keep_only_best': False,
#  'name_suffix': None,
#  'num_bag_folds': 5,
#  'num_bag_sets': 3,
#  'num_stack_levels': 3,
#  'pseudo_data': None,
#  'refit_full': False,
#  'save_space': False,
#  'set_best_to_refit_full': False,
#  'unlabeled_data': None,
#  'use_bag_holdout': False,
#  'verbosity': 4}
# ========================================
# Stack configuration (auto_stack=True): num_stack_levels=3, num_bag_folds=5, num_bag_sets=3
# Saving ./agModels-wings_drag/learner.pkl
# Saving ./agModels-wings_drag/predictor.pkl
# Beginning AutoGluon training ...
# AutoGluon will save models to "./agModels-wings_drag/"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.10
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #51-Ubuntu SMP Mon Jul 4 06:41:22 UTC 2022
# Train Data Rows:    837
# Train Data Columns: 129
# Label Column: drag
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (0.944, 0.051, 0.44523, 0.1125)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    259826.47 MB
# 	Train Data (Original)  Memory Usage: 0.86 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Original Features (exact raw dtype, raw dtype):
# 				('float64', 'float') : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			0.0s = Fit runtime
# 			129 features in original data used to generate 129 features in processed data.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			0.0s = Fit runtime
# 			129 features in original data used to generate 129 features in processed data.
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			0.0s = Fit runtime
# 			129 features in original data used to generate 129 features in processed data.
# 		Skipping CategoryFeatureGenerator: No input feature with required dtypes.
# 		Skipping DatetimeFeatureGenerator: No input feature with required dtypes.
# 		Skipping TextSpecialFeatureGenerator: No input feature with required dtypes.
# 		Skipping TextNgramFeatureGenerator: No input feature with required dtypes.
# 		Skipping IdentityFeatureGenerator: No input feature with required dtypes.
# 		Skipping IsNanFeatureGenerator: No input feature with required dtypes.
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 			Types of features in original data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (exact raw dtype, raw dtype):
# 				('float64', 'float') : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			Types of features in processed data (raw dtype, special dtypes):
# 				('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 			0.0s = Fit runtime
# 			129 features in original data used to generate 129 features in processed data.
# 	Types of features in original data (exact raw dtype, raw dtype):
# 		('float64', 'float') : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 	Types of features in processed data (exact raw dtype, raw dtype):
# 		('float64', 'float') : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# 	0.3s = Fit runtime
# 	129 features in original data used to generate 129 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.86 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.3s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Saving ./agModels-wings_drag/learner.pkl
# Saving ./agModels-wings_drag/utils/data/X.pkl
# Saving ./agModels-wings_drag/utils/data/y.pkl
# AutoGluon will fit 4 stack levels (L1 to L4) ...
# Model configs that will be trained (in order):
# 	KNeighborsUnif_BAG_L1: 	{'weights': 'uniform', 'ag_args': {'valid_stacker': False, 'name_suffix': 'Unif', 'model_type': <class 'autogluon.tabular.models.knn.knn_model.KNNModel'>, 'priority': 100}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	KNeighborsDist_BAG_L1: 	{'weights': 'distance', 'ag_args': {'valid_stacker': False, 'name_suffix': 'Dist', 'model_type': <class 'autogluon.tabular.models.knn.knn_model.KNNModel'>, 'priority': 100}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	LightGBMXT_BAG_L1: 	{'extra_trees': True, 'ag_args': {'name_suffix': 'XT', 'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 90}}
# 	LightGBM_BAG_L1: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 90}}
# 	RandomForestMSE_BAG_L1: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile'], 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_BAG_L1: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 70}}
# 	ExtraTreesMSE_BAG_L1: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile'], 'model_type': <class 'autogluon.tabular.models.xt.xt_model.XTModel'>, 'priority': 60}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	NeuralNetFastAI_BAG_L1: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.fastainn.tabular_nn_fastai.NNFastAiTabularModel'>, 'priority': 50}}
# 	XGBoost_BAG_L1: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.xgboost.xgboost_model.XGBoostModel'>, 'priority': 40}}
# 	NeuralNetTorch_BAG_L1: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 25}}
# 	LightGBMLarge_BAG_L1: 	{'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'name_suffix': 'Large', 'hyperparameter_tune_kwargs': None, 'priority': 0}}
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting KNeighborsUnif_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/utils/model_template.pkl
# 	Dropped 0 of 129 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/model.pkl
# 	-0.093	 = Validation score   (-root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting KNeighborsDist_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/utils/model_template.pkl
# 	Dropped 0 of 129 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/model.pkl
# 	-0.0887	 = Validation score   (-root_mean_squared_error)
# 	0.03s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting LightGBMXT_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L1/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 129 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L1/model.pkl
# 	-0.0842	 = Validation score   (-root_mean_squared_error)
# 	31.53s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: LightGBM_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting LightGBM_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L1/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 129 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L1/model.pkl
# 	-0.0858	 = Validation score   (-root_mean_squared_error)
# 	12.65s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting RandomForestMSE_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/utils/model_template.pkl
# 	Dropped 0 of 129 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/model.pkl
# 	-0.0873	 = Validation score   (-root_mean_squared_error)
# 	2.44s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: CatBoost_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting CatBoost_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 129 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L1/model.pkl
# 	-0.0833	 = Validation score   (-root_mean_squared_error)
# 	111.46s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting ExtraTreesMSE_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/utils/model_template.pkl
# 	Dropped 0 of 129 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/model.pkl
# 	-0.0856	 = Validation score   (-root_mean_squared_error)
# 	1.0s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting NeuralNetFastAI_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 129 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/model.pkl
# 	-0.083	 = Validation score   (-root_mean_squared_error)
# 	7.45s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: XGBoost_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting XGBoost_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L1/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 129 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L1/model.pkl
# 	-0.0865	 = Validation score   (-root_mean_squared_error)
# 	14.7s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting NeuralNetTorch_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 129 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/model.pkl
# 	-0.0812	 = Validation score   (-root_mean_squared_error)
# 	15.13s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Dropped 0 of 129 features.
# 	Dropped 0 of 129 features.
# 	Fitting LightGBMLarge_BAG_L1 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 129 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/model.pkl
# 	-0.0869	 = Validation score   (-root_mean_squared_error)
# 	71.01s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/utils/oof.pkl
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L2: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Fitting model: WeightedEnsemble_L2 ...
# 	Dropped 0 of 11 features.
# 	Dropped 0 of 11 features.
# 	Fitting WeightedEnsemble_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L2/utils/model_template.pkl
# 	Dropped 0 of 11 features.
# Ensemble size: 29
# Ensemble indices: [9, 5, 9, 1, 9, 7, 9, 5, 9, 9, 1, 5, 9, 9, 5, 9, 9, 1, 9, 5, 9, 7, 9, 5, 9, 1, 9, 5, 9]
# Ensemble weights:
# [0.         0.13793103 0.         0.         0.         0.24137931
#  0.         0.06896552 0.         0.55172414 0.        ]
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L2/model.pkl
# 	-0.0799	 = Validation score   (-root_mean_squared_error)
# 	0.98s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Model configs that will be trained (in order):
# 	LightGBMXT_BAG_L2: 	{'extra_trees': True, 'ag_args': {'name_suffix': 'XT', 'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 90}}
# 	LightGBM_BAG_L2: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 90}}
# 	RandomForestMSE_BAG_L2: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile'], 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_BAG_L2: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 70}}
# 	ExtraTreesMSE_BAG_L2: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile'], 'model_type': <class 'autogluon.tabular.models.xt.xt_model.XTModel'>, 'priority': 60}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	NeuralNetFastAI_BAG_L2: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.fastainn.tabular_nn_fastai.NNFastAiTabularModel'>, 'priority': 50}}
# 	XGBoost_BAG_L2: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.xgboost.xgboost_model.XGBoostModel'>, 'priority': 40}}
# 	NeuralNetTorch_BAG_L2: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.tabular_nn.torch.tabular_nn_torch.TabularNeuralNetTorchModel'>, 'priority': 25}}
# 	LightGBMLarge_BAG_L2: 	{'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'name_suffix': 'Large', 'hyperparameter_tune_kwargs': None, 'priority': 0}}
# Fitting 9 L2 models ...
# Loading: ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/utils/oof.pkl
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting LightGBMXT_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L2/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 140 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L2/model.pkl
# 	-0.0825	 = Validation score   (-root_mean_squared_error)
# 	2.76s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: LightGBM_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting LightGBM_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L2/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 140 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L2/model.pkl
# 	-0.0833	 = Validation score   (-root_mean_squared_error)
# 	8.81s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting RandomForestMSE_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L2/utils/model_template.pkl
# 	Dropped 0 of 140 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L2/model.pkl
# 	-0.0825	 = Validation score   (-root_mean_squared_error)
# 	2.28s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: CatBoost_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting CatBoost_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L2/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 140 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L2/model.pkl
# 	-0.0817	 = Validation score   (-root_mean_squared_error)
# 	23.83s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting ExtraTreesMSE_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L2/utils/model_template.pkl
# 	Dropped 0 of 140 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L2/model.pkl
# 	-0.0817	 = Validation score   (-root_mean_squared_error)
# 	2.5s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting NeuralNetFastAI_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L2/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 140 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L2/model.pkl
# 	-0.0835	 = Validation score   (-root_mean_squared_error)
# 	7.72s	 = Training   runtime
# 	0.97s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: XGBoost_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting XGBoost_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L2/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 140 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L2/model.pkl
# 	-0.0817	 = Validation score   (-root_mean_squared_error)
# 	12.21s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting NeuralNetTorch_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L2/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 140 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L2/model.pkl
# 	-0.0829	 = Validation score   (-root_mean_squared_error)
# 	19.56s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Dropped 0 of 140 features.
# 	Dropped 0 of 140 features.
# 	Fitting LightGBMLarge_BAG_L2 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L2/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L2/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 140 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L2/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L2/model.pkl
# 	-0.0824	 = Validation score   (-root_mean_squared_error)
# 	213.65s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L2/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L2/utils/oof.pkl
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L3: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Fitting model: WeightedEnsemble_L3 ...
# 	Dropped 0 of 9 features.
# 	Dropped 0 of 9 features.
# 	Fitting WeightedEnsemble_L3 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L3/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L3/utils/model_template.pkl
# 	Dropped 0 of 9 features.
# Ensemble size: 80
# Ensemble indices: [3, 6, 7, 4, 5, 6, 7, 6, 4, 8, 7, 6, 5, 4, 6, 7, 6, 4, 7, 6, 5, 4, 6, 7, 8, 6, 7, 4, 5, 6, 7, 6, 4, 6, 7, 4, 6, 5, 7, 8, 4, 6, 7, 6, 4, 5, 6, 7, 4, 6, 7, 8, 6, 5, 7, 6, 4, 7, 4, 6, 5, 6, 6, 7, 5, 6, 4, 7, 6, 4, 8, 4, 7, 7, 5, 6, 7, 4, 6, 6]
# Ensemble weights:
# [0.     0.     0.     0.0125 0.2125 0.125  0.3375 0.25   0.0625]
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L3/utils/oof.pkl
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L3/model.pkl
# 	-0.0806	 = Validation score   (-root_mean_squared_error)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Model configs that will be trained (in order):
# 	LightGBMXT_BAG_L3: 	{'extra_trees': True, 'ag_args': {'name_suffix': 'XT', 'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 90}}
# 	LightGBM_BAG_L3: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.lgb.lgb_model.LGBModel'>, 'priority': 90}}
# 	RandomForestMSE_BAG_L3: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile'], 'model_type': <class 'autogluon.tabular.models.rf.rf_model.RFModel'>, 'priority': 80}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	CatBoost_BAG_L3: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.catboost.catboost_model.CatBoostModel'>, 'priority': 70}}
# 	ExtraTreesMSE_BAG_L3: 	{'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile'], 'model_type': <class 'autogluon.tabular.models.xt.xt_model.XTModel'>, 'priority': 60}, 'ag_args_ensemble': {'use_child_oof': True}}
# 	NeuralNetFastAI_BAG_L3: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.fastainn.tabular_nn_fastai.NNFastAiTabularModel'>, 'priority': 50}}
# 	XGBoost_BAG_L3: 	{'ag_args': {'model_type': <class 'autogluon.tabular.models.xgboost.xgboost_model.XGBoostModel'>, 'priority': 40}}
# ...
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBMXT_BAG_L4/model.pkl
# 	-0.0843	 = Validation score   (-root_mean_squared_error)
# 	28.61s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: LightGBM_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting LightGBM_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L4/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 138 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBM_BAG_L4/model.pkl
# 	-0.0865	 = Validation score   (-root_mean_squared_error)
# 	6.63s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: RandomForestMSE_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting RandomForestMSE_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L4/utils/model_template.pkl
# 	Dropped 0 of 138 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/RandomForestMSE_BAG_L4/model.pkl
# 	-0.0851	 = Validation score   (-root_mean_squared_error)
# 	1.49s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: CatBoost_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting CatBoost_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L4/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 138 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/CatBoost_BAG_L4/model.pkl
# 	-0.0842	 = Validation score   (-root_mean_squared_error)
# 	18.09s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: ExtraTreesMSE_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting ExtraTreesMSE_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L4/utils/model_template.pkl
# 	Dropped 0 of 138 features.
# 	`use_child_oof` was specified for this model. It will function similarly to a bagged model, but will only fit one child model.
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L4/model.pkl
# 	-0.0839	 = Validation score   (-root_mean_squared_error)
# 	1.3s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: NeuralNetFastAI_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting NeuralNetFastAI_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L4/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 138 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L4/model.pkl
# 	-0.0821	 = Validation score   (-root_mean_squared_error)
# 	4.3s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: XGBoost_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting XGBoost_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L4/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 138 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/XGBoost_BAG_L4/model.pkl
# 	-0.086	 = Validation score   (-root_mean_squared_error)
# 	7.58s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: NeuralNetTorch_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting NeuralNetTorch_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L4/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 138 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/NeuralNetTorch_BAG_L4/model.pkl
# 	-0.0829	 = Validation score   (-root_mean_squared_error)
# 	11.23s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Fitting model: LightGBMLarge_BAG_L4 ...
# 	Dropped 0 of 138 features.
# 	Dropped 0 of 138 features.
# 	Fitting LightGBMLarge_BAG_L4 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L4/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L4/utils/model_template.pkl
# Upper level total_num_cpus, num_gpus 40 | 0
# 	Dropped 0 of 138 features.
# minimum_model_resources: {'num_cpus': 1}
# user_cpu_per_job, user_gpu_per_job None | None
# user_ensemble_cpu, user_ensemble_gpu None | None
# Resources info for CpuResourceCalculator: {'resources_per_job': {'cpu': 2}, 'num_parallel_jobs': 15, 'batches': 1, 'cpu_per_job': 2}
# 	Fitting 15 child models (S1F1 - S3F5) | Fitting with ParallelLocalFoldFittingStrategy
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Folding resources per job {'num_gpus': 0, 'num_cpus': 2}
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L4/utils/oof.pkl
# Saving ./agModels-wings_drag/models/LightGBMLarge_BAG_L4/model.pkl
# 	-0.0854	 = Validation score   (-root_mean_squared_error)
# 	76.7s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L4/utils/oof.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L4/utils/oof.pkl
# Model configs that will be trained (in order):
# 	WeightedEnsemble_L5: 	{'ag_args': {'valid_base': False, 'name_bag_suffix': '', 'model_type': <class 'autogluon.core.models.greedy_ensemble.greedy_weighted_ensemble_model.GreedyWeightedEnsembleModel'>, 'priority': 0}, 'ag_args_ensemble': {'save_bag_folds': True}}
# Fitting model: WeightedEnsemble_L5 ...
# 	Dropped 0 of 9 features.
# 	Dropped 0 of 9 features.
# 	Fitting WeightedEnsemble_L5 with 'num_gpus': 0, 'num_cpus': 40
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L5/utils/model_template.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L5/utils/model_template.pkl
# 	Dropped 0 of 9 features.
# Ensemble size: 15
# Ensemble indices: [5, 7, 5, 4, 5, 7, 5, 7, 5, 7, 5, 4, 5, 7, 5]
# Ensemble weights:
# [0.         0.         0.         0.         0.13333333 0.53333333
#  0.         0.33333333 0.        ]
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L5/utils/oof.pkl
# Saving ./agModels-wings_drag/models/WeightedEnsemble_L5/model.pkl
# 	-0.0812	 = Validation score   (-root_mean_squared_error)
# 	0.44s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Saving ./agModels-wings_drag/models/trainer.pkl
# Saving ./agModels-wings_drag/models/trainer.pkl
# Saving ./agModels-wings_drag/models/trainer.pkl
# AutoGluon training complete, total runtime = 915.57s ... Best model: "WeightedEnsemble_L2"
# Loading: ./agModels-wings_drag/models/trainer.pkl
# Saving ./agModels-wings_drag/models/trainer.pkl
# Saving ./agModels-wings_drag/learner.pkl
# Saving ./agModels-wings_drag/predictor.pkl
# Saving ./agModels-wings_drag/__version__ with contents "0.7.0"
# Saving ./agModels-wings_drag/metadata.json
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("./agModels-wings_drag/")

# %%
test_data = test_df.drop(columns=['i', 'name'])
# val_data.head()
y_val = test_data[label]
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
test_data_nolab.head()
# Out:
#          dim_1     dim_2     dim_3     dim_4     dim_5     dim_6     dim_7  \
# 1046 -0.242641 -0.544351 -0.785688  0.915798  0.159682 -0.134473  0.513026
# 657  -0.086765 -0.885193  0.826741 -0.850657  0.465779 -1.419797 -0.319893
# 127   0.993629  0.058908  0.058237 -0.193928 -0.465946  0.194533  0.438341
# 951  -0.238668  0.338577 -0.576213 -0.241772 -0.971682  1.144228  1.083222
# 134  -1.254356  0.557110  0.389810  0.332288 -0.160778 -0.055890 -1.489394
#
#          dim_8     dim_9    dim_10  ...   dim_120   dim_121   dim_122  \
# 1046 -0.386129 -1.244955  0.406885  ...  0.504696 -0.266971  0.339783
# 657   0.348212  0.397075 -1.688038  ...  1.223718 -1.820433  0.109049
# 127  -0.264994 -0.371554  1.000921  ... -1.863156 -0.465709  0.748947
# 951  -2.304590  0.678272 -0.991069  ...  1.038386 -0.669204  1.110296
# 134  -0.652277 -0.348175 -0.549951  ...  0.401014 -2.166166 -0.277220
#
#        dim_123   dim_124   dim_125   dim_126   dim_127   dim_128   lift
# 1046 -0.708615 -0.384231 -0.775731  0.406653 -0.137757  1.354433  0.346
# 657   0.877518 -0.688451 -0.905782  0.322554  0.742038 -0.282902  0.654
# 127  -1.537500  1.178252  0.856316  0.287750  0.008825  0.656394  0.052
# 951   0.581472  0.028183  0.678450 -0.005965 -0.314793 -0.241957  0.604
# 134  -0.422792  0.157305  0.493497 -1.234308 -0.001335  0.454736  0.199
#
# [5 rows x 129 columns]

# %%
# %%capture log_output
# %config InlineBackend.figure_format = 'retina'
# %config Application.log_level = 'DEBUG'
# %config IPCompleter.greedy = True

predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
y_pred = predictor.predict(test_data_nolab)
for item in y_pred:
    print(item)
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_val, y_pred=y_pred, auxiliary_metrics=True)
print(perf)

results = predictor.fit_summary(show_plot=True)
print(results)
print(predictor.leaderboard(test_data, silent=True))

# with open('./output_all_parts.log', 'w') as f:
#     f.write(log_output.stdout)
# Out:
# Loading: ./agModels-wings_drag/predictor.pkl
# Loading: ./agModels-wings_drag/learner.pkl
# Loading: ./agModels-wings_drag/models/trainer.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L2/model.pkl
# Evaluation: root_mean_squared_error on test data: -0.08296561338100417
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -0.08296561338100417,
#     "mean_squared_error": -0.006883293003686257,
#     "mean_absolute_error": -0.05817961138089499,
#     "r2": 0.46211796008999806,
#     "pearsonr": 0.6814670655969325,
#     "median_absolute_error": -0.039285244584083556
# }
# Loading: ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L2/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L3/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L4/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L5/model.pkl
# 0.47036629915237427
# 0.3335382342338562
# 0.43195658922195435
# 0.4288609027862549
# 0.43751829862594604
# 0.5908997654914856
# 0.4010847210884094
# 0.36850205063819885
# 0.35644587874412537
# 0.36648058891296387
# 0.46563971042633057
# 0.49456512928009033
# 0.41071242094039917
# 0.3698299527168274
# 0.6117626428604126
# 0.5627411603927612
# 0.3639877736568451
# 0.5535755157470703
# 0.5714623928070068
# 0.4222415089607239
# 0.4752230942249298
# 0.38462239503860474
# 0.5269132256507874
# 0.48046642541885376
# 0.43018436431884766
# 0.4458569884300232
# 0.5632071495056152
# 0.3982229232788086
# 0.41792139410972595
# 0.3360244631767273
# 0.3987458646297455
# 0.5225263237953186
# 0.42318373918533325
# 0.5020925998687744
# 0.46921032667160034
# 0.3872513175010681
# 0.3877437710762024
# 0.3786271810531616
# 0.336036741733551
# 0.4210362434387207
# 0.42496442794799805
# 0.3872826397418976
# 0.6093036532402039
# 0.3948030471801758
# 0.5237514972686768
# 0.3713464140892029
# 0.3845136761665344
# 0.42671942710876465
# 0.35966092348098755
# 0.32816439867019653
# 0.5685794353485107
# 0.44233694672584534
# 0.4451422095298767
# 0.3372723460197449
# 0.37727850675582886
# 0.34621918201446533
# 0.4223219156265259
# 0.4469732642173767
# 0.43768298625946045
# 0.5768036842346191
# 0.3264509439468384
# 0.417985200881958
# 0.5358451008796692
# 0.5409879684448242
# 0.5479318499565125
# 0.4756980538368225
# 0.5134509205818176
# 0.4774441421031952
# 0.4317835569381714
# 0.40737733244895935
# 0.45044755935668945
# 0.4694517254829407
# 0.6371774673461914
# 0.3267797827720642
# 0.48605623841285706
# 0.49811965227127075
# 0.4164432883262634
# 0.37571433186531067
# 0.38621535897254944
# 0.4808116853237152
# 0.40885984897613525
# 0.4779011309146881
# 0.36573460698127747
# 0.47750818729400635
# 0.3640057146549225
# 0.3422737717628479
# 0.39366865158081055
# 0.4036422371864319
# 0.457874596118927
# 0.4811963438987732
# 0.33936506509780884
# 0.4740031063556671
# 0.5786019563674927
# 0.3944929838180542
# 0.34283891320228577
# 0.41871678829193115
# 0.333712637424469
# 0.4086136221885681
# 0.4960686266422272
# 0.5293653607368469
# 0.5363502502441406
# 0.4744805693626404
# 0.6550210118293762
# 0.45803800225257874
# 0.3990604877471924
# 0.34181928634643555
# 0.4366608262062073
# 0.532611608505249
# 0.4807543158531189
# 0.4036279320716858
# 0.44331231713294983
# 0.39568403363227844
# 0.4039396643638611
# 0.4171263873577118
# 0.5883771777153015
# 0.5124599933624268
# 0.48004859685897827
# 0.5529487729072571
# 0.4585469365119934
# 0.47899478673934937
# 0.4058767557144165
# 0.4358660578727722
# 0.41240185499191284
# 0.3766629099845886
# 0.428119957447052
# 0.45836499333381653
# 0.5167580842971802
# 0.3315200209617615
# 0.44707703590393066
# 0.4549623131752014
# 0.5679175853729248
# 0.4663088917732239
# 0.6242853403091431
# 0.6178522706031799
# 0.4236283302307129
# 0.5451485514640808
# 0.5021427273750305
# 0.4715566337108612
# 0.5586203336715698
# 0.39850664138793945
# 0.4038013517856598
# 0.45141685009002686
# 0.500710129737854
# 0.5220357179641724
# 0.4540269076824188
# 0.4913737177848816
# 0.44284605979919434
# 0.3870686888694763
# 0.4908919036388397
# 0.4070069193840027
# 0.5433211922645569
# 0.5345488786697388
# 0.47754406929016113
# 0.4798482060432434
# 0.3234785199165344
# 0.5010566711425781
# 0.5004482865333557
# 0.44928181171417236
# 0.4186161756515503
# 0.5652185678482056
# 0.5663864016532898
# 0.596159815788269
# 0.45796090364456177
# 0.5206676125526428
# 0.5311259031295776
# 0.5353517532348633
# 0.38628309965133667
# 0.443314790725708
# 0.3373492360115051
# 0.3781546950340271
# 0.41223669052124023
# 0.41621530055999756
# 0.505545973777771
# 0.5285069346427917
# 0.5041687488555908
# 0.4534650444984436
# 0.364474356174469
# 0.4152641296386719
# 0.42921364307403564
# 0.4113728702068329
# 0.35768064856529236
# 0.46589258313179016
# 0.38176554441452026
# 0.5567731857299805
# 0.49660438299179077
# 0.35941654443740845
# 0.3918530344963074
# 0.3859385848045349
# 0.40547633171081543
# 0.5034998059272766
# 0.38096243143081665
# 0.49721530079841614
# 0.5020357370376587
# 0.38900434970855713
# 0.39714550971984863
# 0.44815224409103394
# 0.4683034420013428
# 0.4240400195121765
# 0.4480590522289276
# 0.4390130341053009
# 0.5136258006095886
# 0.4594792127609253
# 0.5379458665847778
# 0.5339608788490295
# 0.4225308895111084
# 0.5288095474243164
# 0.4476051330566406
# 0.42815741896629333
# 0.4663313627243042
# 0.5788573026657104
# Predictions:
#  1046    0.470366
# 657     0.333538
# 127     0.431957
# 951     0.428861
# 134     0.437518
#           ...
# 454     0.528810
# 1043    0.447605
# 53      0.428157
# 1       0.466331
# 775     0.578857
# Name: drag, Length: 210, dtype: float32
# {'root_mean_squared_error': -0.08296561338100417, 'mean_squared_error': -0.006883293003686257, 'mean_absolute_error': -0.05817961138089499, 'r2': 0.46211796008999806, 'pearsonr': 0.6814670655969325, 'median_absolute_error': -0.039285244584083556}
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L2  -0.079922       1.173030  135.041401                0.002641           0.977414            2       True         12
# 1      WeightedEnsemble_L3  -0.080648       5.823020  547.316938                0.002455           0.437335            3       True         22
# 2    NeuralNetTorch_BAG_L1  -0.081158       0.265321   15.130819                0.265321          15.130819            1       True         10
# 3      WeightedEnsemble_L5  -0.081175       8.348041  645.479209                0.000893           0.439331            5       True         42
# 4          CatBoost_BAG_L2  -0.081654       3.551039  291.253467                0.213134          23.827315            2       True         16
# 5     ExtraTreesMSE_BAG_L2  -0.081687       3.570393  269.925388                0.232489           2.499236            2       True         17
# 6           XGBoost_BAG_L2  -0.081700       3.509852  279.633053                0.171947          12.206901            2       True         19
# 7   NeuralNetFastAI_BAG_L4  -0.082144       7.905403  632.514450                0.245005           4.297399            4       True         38
# 8      WeightedEnsemble_L4  -0.082370       7.218715  597.423902                0.002330           0.444093            4       True         32
# 9     LightGBMLarge_BAG_L2  -0.082448       3.837353  481.071429                0.499449         213.645277            2       True         21
# 10  RandomForestMSE_BAG_L2  -0.082477       3.634305  269.707819                0.296400           2.281667            2       True         15
# 11       LightGBMXT_BAG_L2  -0.082522       3.390165  270.190472                0.052260           2.764320            2       True         13
# 12   NeuralNetTorch_BAG_L2  -0.082900       3.730350  286.985192                0.392446          19.559040            2       True         20
# 13         CatBoost_BAG_L3  -0.082925       6.444557  579.804881                0.140027          19.069554            3       True         26
# 14   NeuralNetTorch_BAG_L4  -0.082936       7.872019  639.446683                0.211622          11.229632            4       True         40
# 15  NeuralNetFastAI_BAG_L1  -0.082981       0.264666    7.447729                0.264666           7.447729            1       True          8
# 16         CatBoost_BAG_L1  -0.083277       0.162987  111.457359                0.162987         111.457359            1       True          6
# 17         LightGBM_BAG_L2  -0.083327       3.473211  276.235888                0.135306           8.809736            2       True         14
# 18    ExtraTreesMSE_BAG_L3  -0.083477       6.522809  562.053489                0.218279           1.318163            3       True         27
# 19  NeuralNetFastAI_BAG_L2  -0.083543       4.311101  275.141835                0.973196           7.715683            2       True         18
# 20       LightGBMXT_BAG_L3  -0.083838       6.350626  562.982574                0.046096           2.247247            3       True         23
# 21    ExtraTreesMSE_BAG_L4  -0.083864       7.890521  629.512848                0.230124           1.295797            4       True         37
# 22          XGBoost_BAG_L3  -0.083906       6.427814  568.015393                0.123283           7.280066            3       True         29
# 23       LightGBMXT_BAG_L1  -0.084171       0.360049   31.527683                0.360049          31.527683            1       True          3
# 24         CatBoost_BAG_L4  -0.084197       7.802132  646.303664                0.141735          18.086613            4       True         36
# 25  NeuralNetFastAI_BAG_L3  -0.084225       6.511751  564.571312                0.207220           3.835985            3       True         28
# 26       LightGBMXT_BAG_L4  -0.084289       7.970336  656.825447                0.309939          28.608396            4       True         33
# 27         LightGBM_BAG_L3  -0.084390       6.364045  565.522691                0.059515           4.787364            3       True         24
# 28    LightGBMLarge_BAG_L3  -0.084538       6.427614  583.420247                0.123084          22.684920            3       True         31
# 29  RandomForestMSE_BAG_L3  -0.084760       6.519849  562.253037                0.215318           1.517710            3       True         25
# 30   NeuralNetTorch_BAG_L3  -0.085010       6.527577  565.476042                0.223046           4.740715            3       True         30
# 31  RandomForestMSE_BAG_L4  -0.085055       7.883677  629.704414                0.223280           1.487363            4       True         35
# 32    LightGBMLarge_BAG_L4  -0.085410       7.886320  704.920096                0.225923          76.703045            4       True         41
# 33    ExtraTreesMSE_BAG_L1  -0.085625       0.277706    0.998750                0.277706           0.998750            1       True          7
# 34         LightGBM_BAG_L1  -0.085794       0.152583   12.651275                0.152583          12.651275            1       True          4
# 35          XGBoost_BAG_L4  -0.085980       7.795752  635.796094                0.135355           7.579043            4       True         39
# 36         LightGBM_BAG_L4  -0.086475       7.726198  634.844154                0.065801           6.627103            4       True         34
# 37          XGBoost_BAG_L1  -0.086539       0.248768   14.704379                0.248768          14.704379            1       True          9
# 38    LightGBMLarge_BAG_L1  -0.086912       0.280842   71.014368                0.280842          71.014368            1       True         11
# 39  RandomForestMSE_BAG_L1  -0.087257       0.207693    2.436503                0.207693           2.436503            1       True          5
# 40   KNeighborsDist_BAG_L1  -0.088692       0.477416    0.028080                0.477416           0.028080            1       True          2
# 41   KNeighborsUnif_BAG_L1  -0.093038       0.639875    0.029207                0.639875           0.029207            1       True          1
# Number of models trained: 42
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_XGBoost'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: True  (with 5 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]
# /home/xli/anaconda3/envs/surrogate_autogluon/lib/python3.10/site-packages/autogluon/core/utils/plots.py:138: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# Loading: ./agModels-wings_drag/models/KNeighborsUnif_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L1/model.pkl
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN', 'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN', 'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB', 'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB', 'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF', 'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost', 'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT', 'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost', 'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB', 'WeightedEnsemble_L2': 'WeightedEnsembleModel', 'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB', 'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB', 'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF', 'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost', 'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT', 'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost', 'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB', 'WeightedEnsemble_L3': 'WeightedEnsembleModel', 'LightGBMXT_BAG_L3': 'StackerEnsembleModel_LGB', 'LightGBM_BAG_L3': 'StackerEnsembleModel_LGB', 'RandomForestMSE_BAG_L3': 'StackerEnsembleModel_RF', 'CatBoost_BAG_L3': 'StackerEnsembleModel_CatBoost', 'ExtraTreesMSE_BAG_L3': 'StackerEnsembleModel_XT', 'NeuralNetFastAI_BAG_L3': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_BAG_L3': 'StackerEnsembleModel_XGBoost', 'NeuralNetTorch_BAG_L3': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBMLarge_BAG_L3': 'StackerEnsembleModel_LGB', 'WeightedEnsemble_L4': 'WeightedEnsembleModel', 'LightGBMXT_BAG_L4': 'StackerEnsembleModel_LGB', 'LightGBM_BAG_L4': 'StackerEnsembleModel_LGB', 'RandomForestMSE_BAG_L4': 'StackerEnsembleModel_RF', 'CatBoost_BAG_L4': 'StackerEnsembleModel_CatBoost', 'ExtraTreesMSE_BAG_L4': 'StackerEnsembleModel_XT', 'NeuralNetFastAI_BAG_L4': 'StackerEnsembleModel_NNFastAiTabular', 'XGBoost_BAG_L4': 'StackerEnsembleModel_XGBoost', 'NeuralNetTorch_BAG_L4': 'StackerEnsembleModel_TabularNeuralNetTorch', 'LightGBMLarge_BAG_L4': 'StackerEnsembleModel_LGB', 'WeightedEnsemble_L5': 'WeightedEnsembleModel'}, 'model_performance': {'KNeighborsUnif_BAG_L1': -0.09303817749860924, 'KNeighborsDist_BAG_L1': -0.08869154204872658, 'LightGBMXT_BAG_L1': -0.08417122697639236, 'LightGBM_BAG_L1': -0.0857938775685687, 'RandomForestMSE_BAG_L1': -0.08725678101374552, 'CatBoost_BAG_L1': -0.0832765245993478, 'ExtraTreesMSE_BAG_L1': -0.0856248261528113, 'NeuralNetFastAI_BAG_L1': -0.08298124675792419, 'XGBoost_BAG_L1': -0.08653949727985939, 'NeuralNetTorch_BAG_L1': -0.08115763270539833, 'LightGBMLarge_BAG_L1': -0.08691151298768134, 'WeightedEnsemble_L2': -0.07992210909756517, 'LightGBMXT_BAG_L2': -0.08252210828823862, 'LightGBM_BAG_L2': -0.08332682228145541, 'RandomForestMSE_BAG_L2': -0.08247683364194675, 'CatBoost_BAG_L2': -0.08165435706994566, 'ExtraTreesMSE_BAG_L2': -0.08168725658643952, 'NeuralNetFastAI_BAG_L2': -0.08354298043883715, 'XGBoost_BAG_L2': -0.08170013929546982, 'NeuralNetTorch_BAG_L2': -0.08290032967213799, 'LightGBMLarge_BAG_L2': -0.08244762128655293, 'WeightedEnsemble_L3': -0.08064842549257313, 'LightGBMXT_BAG_L3': -0.083838183322245, 'LightGBM_BAG_L3': -0.08439010065929434, 'RandomForestMSE_BAG_L3': -0.08476040248579503, 'CatBoost_BAG_L3': -0.08292456342890499, 'ExtraTreesMSE_BAG_L3': -0.08347704948497846, 'NeuralNetFastAI_BAG_L3': -0.0842249902338191, 'XGBoost_BAG_L3': -0.08390559321908965, 'NeuralNetTorch_BAG_L3': -0.08501031244681576, 'LightGBMLarge_BAG_L3': -0.08453758191880346, 'WeightedEnsemble_L4': -0.08237044980688106, 'LightGBMXT_BAG_L4': -0.08428927996198751, 'LightGBM_BAG_L4': -0.08647498097911235, 'RandomForestMSE_BAG_L4': -0.08505509945981989, 'CatBoost_BAG_L4': -0.08419692910945684, 'ExtraTreesMSE_BAG_L4': -0.08386391937738985, 'NeuralNetFastAI_BAG_L4': -0.08214412560979617, 'XGBoost ...
# 0      WeightedEnsemble_L2  -0.079922       1.173030  135.041401
# 1      WeightedEnsemble_L3  -0.080648       5.823020  547.316938
# 2    NeuralNetTorch_BAG_L1  -0.081158       0.265321   15.130819
# 3      WeightedEnsemble_L5  -0.081175       8.348041  645.479209
# 4          CatBoost_BAG_L2  -0.081654       3.551039  291.253467
# 5     ExtraTreesMSE_BAG_L2  -0.081687       3.570393  269.925388
# 6           XGBoost_BAG_L2  -0.081700       3.509852  279.633053
# 7   NeuralNetFastAI_BAG_L4  -0.082144       7.905403  632.514450
# 8      WeightedEnsemble_L4  -0.082370       7.218715  597.423902
# 9     LightGBMLarge_BAG_L2  -0.082448       3.837353  481.071429
# 10  RandomForestMSE_BAG_L2  -0.082477       3.634305  269.707819
# 11       LightGBMXT_BAG_L2  -0.082522       3.390165  270.190472
# 12   NeuralNetTorch_BAG_L2  -0.082900       3.730350  286.985192
# 13         CatBoost_BAG_L3  -0.082925       6.444557  579.804881
# 14   NeuralNetTorch_BAG_L4  -0.082936       7.872019  639.446683
# 15  NeuralNetFastAI_BAG_L1  -0.082981       0.264666    7.447729
# 16         CatBoost_BAG_L1  -0.083277       0.162987  111.457359
# 17         LightGBM_BAG_L2  -0.083327       3.473211  276.235888
# 18    ExtraTreesMSE_BAG_L3  -0.083477       6.522809  562.053489
# 19  NeuralNetFastAI_BAG_L2  -0.083543       4.311101  275.141835
# 20       LightGBMXT_BAG_L3  -0.083838       6.350626  562.982574
# 21    ExtraTreesMSE_BAG_L4  -0.083864       7.890521  629.512848
# 22          XGBoost_BAG_L3  -0.083906       6.427814  568.015393
# 23       LightGBMXT_BAG_L1  -0.084171       0.360049   31.527683
# 24         CatBoost_BAG_L4  -0.084197       7.802132  646.303664
# 25  NeuralNetFastAI_BAG_L3  -0.084225       6.511751  564.571312
# 26       LightGBMXT_BAG_L4  -0.084289       7.970336  656.825447
# 27         LightGBM_BAG_L3  -0.084390       6.364045  565.522691
# 28    LightGBMLarge_BAG_L3  -0.084538       6.427614  583.420247
# 29  RandomForestMSE_BAG_L3  -0.084760       6.519849  562.253037
# 30   NeuralNetTorch_BAG_L3  -0.085010       6.527577  565.476042
# 31  RandomForestMSE_BAG_L4  -0.085055       7.883677  629.704414
# 32    LightGBMLarge_BAG_L4  -0.085410       7.886320  704.920096
# 33    ExtraTreesMSE_BAG_L1  -0.085625       0.277706    0.998750
# 34         LightGBM_BAG_L1  -0.085794       0.152583   12.651275
# 35          XGBoost_BAG_L4  -0.085980       7.795752  635.796094
# 36         LightGBM_BAG_L4  -0.086475       7.726198  634.844154
# 37          XGBoost_BAG_L1  -0.086539       0.248768   14.704379
# 38    LightGBMLarge_BAG_L1  -0.086912       0.280842   71.014368
# 39  RandomForestMSE_BAG_L1  -0.087257       0.207693    2.436503
# 40   KNeighborsDist_BAG_L1  -0.088692       0.477416    0.028080
# 41   KNeighborsUnif_BAG_L1  -0.093038       0.639875    0.029207
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.002641           0.977414            2       True
# 1                 0.002455           0.437335            3       True
# 2                 0.265321          15.130819            1       True
# 3                 0.000893           0.439331            5       True
# 4                 0.213134          23.827315            2       True
# 5                 0.232489           2.499236            2       True
# 6                 0.171947          12.206901            2       True
# 7                 0.245005           4.297399            4       True
# 8                 0.002330           0.444093            4       True
# 9                 0.499449         213.645277            2       True
# 10                0.296400           2.281667            2       True
# 11                0.052260           2.764320            2       True
# 12                0.392446          19.559040            2       True
# 13                0.140027          19.069554            3       True
# 14                0.211622          11.229632            4       True
# 15                0.264666           7.447729            1       True
# 16                0.162987         111.457359            1       True
# 17                0.135306           8.809736            2       True
# 18                0.218279           1.318163            3       True
# 19                0.973196           7.715683            2       True
# 20                0.046096           2.247247            3       True
# 21                0.230124           1.295797            4       True
# 22                0.123283           7.280066            3       True
# 23                0.360049          31.527683            1       True
# 24                0.141735          18.086613            4       True
# 25                0.207220           3.835985            3       True
# 26                0.309939          28.608396            4       True
# 27                0.059515           4.787364            3       True
# 28                0.123084          22.684920            3       True
# 29                0.215318           1.517710            3       True
# 30                0.223046           4.740715            3       True
# 31                0.223280           1.487363            4       True
# 32                0.225923          76.703045            4       True
# 33                0.277706           0.998750            1       True
# 34                0.152583          12.651275            1       True
# 35                0.135355           7.579043            4       True
# 36                0.065801           6.627103            4       True
# 37                0.248768          14.704379            1       True
# 38                0.280842          71.014368            1       True
# 39                0.207693           2.436503            1       True
# 40                0.477416           0.028080            1       True
# 41                0.639875           0.029207            1       True
#
#     fit_order
# 0          12
# 1          22
# 2          10
# 3          42
# 4          16
# 5          17
# 6          19
# 7          38
# 8          32
# 9          21
# 10         15
# 11         13
# 12         20
# 13         26
# 14         40
# 15          8
# 16          6
# 17         14
# 18         27
# 19         18
# 20         23
# 21         37
# 22         29
# 23          3
# 24         36
# 25         28
# 26         33
# 27         24
# 28         31
# 29         25
# 30         30
# 31         35
# 32         41
# 33          7
# 34          4
# 35         39
# 36         34
# 37          9
# 38         11
# 39          5
# 40          2
# 41          1  }
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L2/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L2/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L3/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L3/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L4/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMXT_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBM_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/RandomForestMSE_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/ExtraTreesMSE_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/XGBoost_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/LightGBMLarge_BAG_L4/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L5/model.pkl
# Model scores:
# {'KNeighborsUnif_BAG_L1': -0.10067791823203051, 'KNeighborsDist_BAG_L1': -0.09610516239979694, 'LightGBMXT_BAG_L1': -0.08356595044536043, 'LightGBM_BAG_L1': -0.08570080948176555, 'RandomForestMSE_BAG_L1': -0.08906672177480018, 'CatBoost_BAG_L1': -0.0857521074212944, 'ExtraTreesMSE_BAG_L1': -0.088909795755424, 'NeuralNetFastAI_BAG_L1': -0.08061449975492986, 'XGBoost_BAG_L1': -0.0861125043522129, 'NeuralNetTorch_BAG_L1': -0.08334406644366144, 'LightGBMLarge_BAG_L1': -0.0874841255572628, 'WeightedEnsemble_L2': -0.08296561338100417, 'LightGBMXT_BAG_L2': -0.08215362248183125, 'LightGBM_BAG_L2': -0.08320992929275028, 'RandomForestMSE_BAG_L2': -0.08305831212929521, 'CatBoost_BAG_L2': -0.08196456122078803, 'ExtraTreesMSE_BAG_L2': -0.08263913675656696, 'NeuralNetFastAI_BAG_L2': -0.08305409124015975, 'XGBoost_BAG_L2': -0.08221953245722576, 'NeuralNetTorch_BAG_L2': -0.0823623109131751, 'LightGBMLarge_BAG_L2': -0.08407622459279519, 'WeightedEnsemble_L3': -0.08157483993535114, 'LightGBMXT_BAG_L3': -0.0833800152436743, 'LightGBM_BAG_L3': -0.08398023533817364, 'RandomForestMSE_BAG_L3': -0.0851249929649599, 'CatBoost_BAG_L3': -0.08213287725645052, 'ExtraTreesMSE_BAG_L3': -0.08376094788043649, 'NeuralNetFastAI_BAG_L3': -0.08201238798842798, 'XGBoost_BAG_L3': -0.08322554093198316, 'NeuralNetTorch_BAG_L3': -0.08315713458921478, 'LightGBMLarge_BAG_L3': -0.08305318268297768, 'WeightedEnsemble_L4': -0.08178399447740371, 'LightGBMXT_BAG_L4': -0.08369847138047949, 'LightGBM_BAG_L4': -0.08516930695204997, 'RandomForestMSE_BAG_L4': -0.0848088043621015, 'CatBoost_BAG_L4': -0.08283605467069755, 'ExtraTreesMSE_BAG_L4': -0.0839126679631866, 'NeuralNetFastAI_BAG_L4': -0.0810286149963593, 'XGBoost_BAG_L4': -0.08471495345781657, 'NeuralNetTorch_BAG_L4': -0.0830696382756199, 'LightGBMLarge_BAG_L4': -0.0857778269273008, 'WeightedEnsemble_L5': -0.08101091199250522}
#                      model  score_test  score_val  pred_time_test  \
# 0   NeuralNetFastAI_BAG_L1   -0.080614  -0.082981        0.266239
# 1      WeightedEnsemble_L5   -0.081011  -0.081175        7.497652
# 2   NeuralNetFastAI_BAG_L4   -0.081029  -0.082144        7.165104
# 3      WeightedEnsemble_L3   -0.081575  -0.080648        5.026024
# 4      WeightedEnsemble_L4   -0.081784  -0.082370        6.293958
# 5          CatBoost_BAG_L2   -0.081965  -0.081654        2.797598
# 6   NeuralNetFastAI_BAG_L3   -0.082012  -0.084225        5.643897
# 7          CatBoost_BAG_L3   -0.082133  -0.082925        5.469495
# 8        LightGBMXT_BAG_L2   -0.082154  -0.082522        2.750088
# 9           XGBoost_BAG_L2   -0.082220  -0.081700        2.884792
# 10   NeuralNetTorch_BAG_L2   -0.082362  -0.082900        2.866781
# 11    ExtraTreesMSE_BAG_L2   -0.082639  -0.081687        2.865007
# 12         CatBoost_BAG_L4   -0.082836  -0.084197        6.994007
# 13     WeightedEnsemble_L2   -0.082966  -0.079922        0.630866
# 14    LightGBMLarge_BAG_L3   -0.083053  -0.084538        5.605136
# 15  NeuralNetFastAI_BAG_L2   -0.083054  -0.083543        2.983253
# 16  RandomForestMSE_BAG_L2   -0.083058  -0.082477        2.899757
# 17   NeuralNetTorch_BAG_L4   -0.083070  -0.082936        7.028839
# 18   NeuralNetTorch_BAG_L3   -0.083157  -0.085010        5.511360
# 19         LightGBM_BAG_L2   -0.083210  -0.083327        2.738790
# 20          XGBoost_BAG_L3   -0.083226  -0.083906        5.537728
# 21   NeuralNetTorch_BAG_L1   -0.083344  -0.081158        0.155741
# 22       LightGBMXT_BAG_L3   -0.083380  -0.083838        5.441879
# 23       LightGBMXT_BAG_L1   -0.083566  -0.084171        0.678561
# 24       LightGBMXT_BAG_L4   -0.083698  -0.084289        7.443142
# 25    ExtraTreesMSE_BAG_L3   -0.083761  -0.083477        5.526187
# 26    ExtraTreesMSE_BAG_L4   -0.083913  -0.083864        7.055002
# 27         LightGBM_BAG_L3   -0.083980  -0.084390        5.424326
# 28    LightGBMLarge_BAG_L2   -0.084076  -0.082448        4.040216
# 29          XGBoost_BAG_L4   -0.084715  -0.085980        7.086249
# 30  RandomForestMSE_BAG_L4   -0.084809  -0.085055        7.059046
# 31  RandomForestMSE_BAG_L3   -0.085125  -0.084760        5.527062
# 32         LightGBM_BAG_L4   -0.085169  -0.086475        6.959020
# 33         LightGBM_BAG_L1   -0.085701  -0.085794        0.149554
# 34         CatBoost_BAG_L1   -0.085752  -0.083277        0.140510
# 35    LightGBMLarge_BAG_L4   -0.085778  -0.085410        7.393516
# 36          XGBoost_BAG_L1   -0.086113  -0.086539        0.321867
# 37    LightGBMLarge_BAG_L1   -0.087484  -0.086912        0.509335
# 38    ExtraTreesMSE_BAG_L1   -0.088910  -0.085625        0.173614
# 39  RandomForestMSE_BAG_L1   -0.089067  -0.087257        0.174619
# 40   KNeighborsDist_BAG_L1   -0.096105  -0.088692        0.059129
# 41   KNeighborsUnif_BAG_L1   -0.100678  -0.093038        0.055235
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.264666    7.447729                 0.266239
# 1        8.348041  645.479209                 0.006094
# 2        7.905403  632.514450                 0.286410
# 3        5.823020  547.316938                 0.010399
# 4        7.218715  597.423902                 0.009479
# 5        3.551039  291.253467                 0.113194
# 6        6.511751  564.571312                 0.292850
# 7        6.444557  579.804881                 0.118448
# 8        3.390165  270.190472                 0.065684
# 9        3.509852  279.633053                 0.200387
# 10       3.730350  286.985192                 0.182376
# 11       3.570393  269.925388                 0.180603
# 12       7.802132  646.303664                 0.115313
# 13       1.173030  135.041401                 0.009245
# 14       6.427614  583.420247                 0.254089
# 15       4.311101  275.141835                 0.298849
# 16       3.634305  269.707819                 0.215353
# 17       7.872019  639.446683                 0.150145
# 18       6.527577  565.476042                 0.160313
# 19       3.473211  276.235888                 0.054386
# 20       6.427814  568.015393                 0.186681
# 21       0.265321   15.130819                 0.155741
# 22       6.350626  562.982574                 0.090832
# 23       0.360049   31.527683                 0.678561
# 24       7.970336  656.825447                 0.564448
# 25       6.522809  562.053489                 0.175140
# 26       7.890521  629.512848                 0.176308
# 27       6.364045  565.522691                 0.073279
# 28       3.837353  481.071429                 1.355812
# 29       7.795752  635.796094                 0.207555
# 30       7.883677  629.704414                 0.180352
# 31       6.519849  562.253037                 0.176015
# 32       7.726198  634.844154                 0.080326
# 33       0.152583   12.651275                 0.149554
# 34       0.162987  111.457359                 0.140510
# 35       7.886320  704.920096                 0.514822
# 36       0.248768   14.704379                 0.321867
# 37       0.280842   71.014368                 0.509335
# 38       0.277706    0.998750                 0.173614
# 39       0.207693    2.436503                 0.174619
# 40       0.477416    0.028080                 0.059129
# 41       0.639875    0.029207                 0.055235
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.264666           7.447729            1       True
# 1                 0.000893           0.439331            5       True
# 2                 0.245005           4.297399            4       True
# 3                 0.002455           0.437335            3       True
# 4                 0.002330           0.444093            4       True
# 5                 0.213134          23.827315            2       True
# 6                 0.207220           3.835985            3       True
# 7                 0.140027          19.069554            3       True
# 8                 0.052260           2.764320            2       True
# 9                 0.171947          12.206901            2       True
# 10                0.392446          19.559040            2       True
# 11                0.232489           2.499236            2       True
# 12                0.141735          18.086613            4       True
# 13                0.002641           0.977414            2       True
# 14                0.123084          22.684920            3       True
# 15                0.973196           7.715683            2       True
# 16                0.296400           2.281667            2       True
# 17                0.211622          11.229632            4       True
# 18                0.223046           4.740715            3       True
# 19                0.135306           8.809736            2       True
# 20                0.123283           7.280066            3       True
# 21                0.265321          15.130819            1       True
# 22                0.046096           2.247247            3       True
# 23                0.360049          31.527683            1       True
# 24                0.309939          28.608396            4       True
# 25                0.218279           1.318163            3       True
# 26                0.230124           1.295797            4       True
# 27                0.059515           4.787364            3       True
# 28                0.499449         213.645277            2       True
# 29                0.135355           7.579043            4       True
# 30                0.223280           1.487363            4       True
# 31                0.215318           1.517710            3       True
# 32                0.065801           6.627103            4       True
# 33                0.152583          12.651275            1       True
# 34                0.162987         111.457359            1       True
# 35                0.225923          76.703045            4       True
# 36                0.248768          14.704379            1       True
# 37                0.280842          71.014368            1       True
# 38                0.277706           0.998750            1       True
# 39                0.207693           2.436503            1       True
# 40                0.477416           0.028080            1       True
# 41                0.639875           0.029207            1       True
#
#     fit_order
# 0           8
# 1          42
# 2          38
# 3          22
# 4          32
# 5          16
# 6          28
# 7          26
# 8          13
# 9          19
# 10         20
# 11         17
# 12         36
# 13         12
# 14         31
# 15         18
# 16         15
# 17         40
# 18         30
# 19         14
# 20         29
# 21         10
# 22         23
# 23          3
# 24         33
# 25         27
# 26         37
# 27         24
# 28         21
# 29         39
# 30         35
# 31         25
# 32         34
# 33          4
# 34          6
# 35         41
# 36          9
# 37         11
# 38          7
# 39          5
# 40          2
# 41          1

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
# Out:
# AutoGluon infers problem type is:  regression
# AutoGluon identified the following types of features:
# ('float', []) : 129 | ['dim_1', 'dim_2', 'dim_3', 'dim_4', 'dim_5', ...]

# %%
train_data_pred = predictor.predict(train_data)
test_data_pred = predictor.predict(test_data)

import numpy as np
#save np array y_train_hat to a csv file
np.savetxt(f'./{data_name}_vectors_y_test_hat_{label}.csv', test_data_pred, delimiter=',')
np.savetxt(f'./{data_name}_vectors_y_train_hat_{label}.csv', train_data_pred, delimiter=',')
# Out:
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L2/model.pkl
# Loading: ./agModels-wings_drag/models/CatBoost_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/KNeighborsDist_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetFastAI_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/NeuralNetTorch_BAG_L1/model.pkl
# Loading: ./agModels-wings_drag/models/WeightedEnsemble_L2/model.pkl
